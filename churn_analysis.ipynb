# %%
import pandas as pd

df = pd.read_csv("data/raw_churn.csv")

# Remove duplicates
df = df.drop_duplicates()

# Convert TotalCharges to numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors='coerce')

# Drop null rows
df = df.dropna()

# Convert Churn to binary
df["Churn_Flag"] = df["Churn"].map({"Yes":1, "No":0})

# Create tenure group
df["Tenure_Group"] = pd.cut(df["tenure"],
                            bins=[0,12,24,36,48,60,72],
                            labels=["0-12","12-24","24-36","36-48","48-60","60+"])

df.to_csv("data/cleaned_churn.csv", index=False)

print("Data cleaned successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data/raw_churn.csv")
#       5 # Remove duplicates
#       6 df = df.drop_duplicates()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("D:/Future_DS_02/data/raw_churn.csv")

# Remove duplicates
df = df.drop_duplicates()

# Convert TotalCharges to numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors='coerce')

# Drop null rows
df = df.dropna()

# Convert Churn to binary
df["Churn_Flag"] = df["Churn"].map({"Yes":1, "No":0})

# Create tenure group
df["Tenure_Group"] = pd.cut(df["tenure"],
                            bins=[0,12,24,36,48,60,72],
                            labels=["0-12","12-24","24-36","36-48","48-60","60+"])

df.to_csv("D:/Future_DS_02/data/cleaned_churn.csv", index=False)

print("Data cleaned successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("D:/Future_DS_02/data/raw_churn.csv")
#       5 # Remove duplicates
#       6 df = df.drop_duplicates()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("data/raw_churn.csv")

# Remove duplicates
df = df.drop_duplicates()

# Convert TotalCharges to numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors='coerce')

# Drop null rows
df = df.dropna()

# Convert Churn to binary
df["Churn_Flag"] = df["Churn"].map({"Yes":1, "No":0})

# Create tenure group
df["Tenure_Group"] = pd.cut(df["tenure"],
                            bins=[0,12,24,36,48,60,72],
                            labels=["0-12","12-24","24-36","36-48","48-60","60+"])

df.to_csv("data/cleaned_churn.csv", index=False)

print("Data cleaned successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data/raw_churn.csv")
#       5 # Remove duplicates
#       6 df = df.drop_duplicates()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("D:/Future_DS_02/data/raw_churn.csv")

# Remove duplicates
df = df.drop_duplicates()

# Convert TotalCharges to numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors='coerce')

# Drop null rows
df = df.dropna()

# Convert Churn to binary
df["Churn_Flag"] = df["Churn"].map({"Yes":1, "No":0})

# Create tenure group
df["Tenure_Group"] = pd.cut(df["tenure"],
                            bins=[0,12,24,36,48,60,72],
                            labels=["0-12","12-24","24-36","36-48","48-60","60+"])

df.to_csv("D:/Future_DS_02/data/cleaned_churn.csv", index=False)

print("Data cleaned successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("D:/Future_DS_02/data/raw_churn.csv")
#       5 # Remove duplicates
#       6 df = df.drop_duplicates()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("D:/Future_DS_02/data/raw_churn.csv")

# Remove duplicates
df = df.drop_duplicates()

# Convert TotalCharges to numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors='coerce')

# Drop null rows
df = df.dropna()

# Convert Churn to binary
df["Churn_Flag"] = df["Churn"].map({"Yes":1, "No":0})

# Create tenure group
df["Tenure_Group"] = pd.cut(df["tenure"],
                            bins=[0,12,24,36,48,60,72],
                            labels=["0-12","12-24","24-36","36-48","48-60","60+"])

df.to_csv("D:/Future_DS_02/data/cleaned_churn.csv", index=False)

print("Data cleaned successfully!")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("D:/Future_DS_02/data/raw_churn.csv")
#       5 # Remove duplicates
#       6 df = df.drop_duplicates()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("D:/Future_DS_02/data/raw_churn.csv")

# Remove duplicates
df = df.drop_duplicates()

# Convert TotalCharges to numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors='coerce')

# Drop null rows
df = df.dropna()

# Convert Churn to binary
df["Churn_Flag"] = df["Churn"].map({"Yes":1, "No":0})

# Create tenure group
df["Tenure_Group"] = pd.cut(df["tenure"],
                            bins=[0,12,24,36,48,60,72],
                            labels=["0-12","12-24","24-36","36-48","48-60","60+"])

df.to_csv("D:/Future_DS_02/data/cleaned_churn.csv", index=False)

print("Data cleaned successfully!")
# Out:
# Data cleaned successfully!
